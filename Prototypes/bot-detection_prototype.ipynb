# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
filepath = 'C:/Users/Rutwik/OneDrive/Desktop/Twitter Bots vs Humans/kaggle_data'
file = filepath + '/training_data.csv'

training_dataset = pd.read_csv(file)

training_dataset.head()
# Out:
#              id                id_str       screen_name  \
# 0  8.160000e+17  "815745789754417152"  "HoustonPokeMap"
# 1  4.843621e+09            4843621225         kernyeahx
# 2  4.303727e+09            4303727112   mattlieberisbot
# 3  3.063139e+09            3063139353         sc_papers
# 4  2.955142e+09            2955142070      lucarivera16
#
#                     location  \
# 0              "Houston, TX"
# 1  Templeville town, MD, USA
# 2                        NaN
# 3                        NaN
# 4      Dublin, United States
#
#                                          description  \
# 0  "Rare and strong PokŽmon in Houston, TX. See m...
# 1  From late 2014 Socium Marketplace will make sh...
# 2  Inspired by the smart, funny folks at @replyal...
# 3                                                NaN
# 4             Inspiring cooks everywhere since 1956.
#
#                          url  followers_count  friends_count  listed_count  \
# 0  "https://t.co/dnWuDbFRkt"             1291              0            10
# 1                        NaN                1            349             0
# 2    https://t.co/P1e1o0m4KC             1086              0            14
# 3                        NaN               33              0             8
# 4                        NaN               11            745             0
#
#                          created_at  favourites_count  verified  \
# 0  "Mon Jan 02 02:25:26 +0000 2017"                 0     False
# 1                     2/1/2016 7:37                38     False
# 2    Fri Nov 20 18:53:22 +0000 2015                 0     False
# 3                   2/25/2015 20:11                 0     False
# 4                    1/1/2015 17:44               146     False
#
#    statuses_count  lang                                             status  \
# 0           78554  "en"  {\r      "created_at": "Sun Mar 12 15:44:04 +0...
# 1              31    en                                                NaN
# 2             713    en  {'retweeted': False, 'is_quote_status': False,...
# 3             676    en  Construction of human anti-tetanus single-chai...
# 4             185    en                                                NaN
#
#    default_profile  default_profile_image has_extended_profile  \
# 0             True                  False                False
# 1             True                  False                False
# 2             True                  False                False
# 3             True                   True                False
# 4            False                  False                False
#
#                    name  bot
# 0  "Houston PokŽ Alert"    1
# 1           Keri Nelson    1
# 2    Matt Lieber Is Bot    1
# 3    single cell papers    1
# 4          lucarivera16    1

# %%
def heat_map(dataset):
    plt.figure(figsize=(10, 6))
    sns.heatmap(dataset.isnull(), yticklabels=False, cbar = False, cmap = 'viridis')
    plt.tight_layout()
    return plt.show()

heat_map(training_dataset)

# %%
bots = training_dataset[training_dataset.bot==1]
nonbots = training_dataset[training_dataset.bot==0]

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title('Bots Friends vs Followers')
sns.regplot(bots.friends_count, bots.followers_count, color='red', label='Bots')
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.tight_layout()

plt.subplot(2,1,2)
plt.title('NonBots Friends vs Followers')
sns.regplot(nonbots.friends_count, nonbots.followers_count, color='blue', label='NonBots')
plt.xlim(0, 100)
plt.ylim(0, 100)

plt.tight_layout()
plt.show()

# %%
bots['friends_by_followers'] = bots.friends_count/bots.followers_count
print(bots[bots.friends_by_followers<1].shape)

nonbots['friends_by_followers'] = nonbots.friends_count/nonbots.followers_count
nonbots[nonbots.friends_by_followers<1].shape
# Out:
# (812, 21)
# (952, 21)

# %%
plt.figure(figsize=(10,5))
plt.plot(bots.listed_count, color='red', label='Bots')
plt.plot(nonbots.listed_count, color='blue', label='NonBots')
plt.legend(loc='upper left')
plt.ylim(10000,20000)
print(bots[(bots.listed_count<5)].shape)
# Out:
# (504, 21)

# %%
bots_listed_count_df = bots[bots.listed_count<16000]
nonbots_listed_count_df = nonbots[nonbots.listed_count<16000]

bots_verified_df = bots_listed_count_df[bots_listed_count_df.verified==False]
bots_screenname_has_bot_df_ = bots_verified_df[(bots_verified_df.screen_name.str.contains("bot", case=False)==True)].shape

# %%
plt.figure(figsize=(12,7))

plt.subplot(2,1,1)
plt.plot(bots_listed_count_df.friends_count, color='red', label='Bots Friends')
plt.plot(nonbots_listed_count_df.friends_count, color='blue', label='NonBots Friends')
plt.legend(loc='upper left')

plt.subplot(2,1,2)
plt.plot(bots_listed_count_df.followers_count, color='red', label='Bots Followers')
plt.plot(nonbots_listed_count_df.followers_count, color='blue', label='NonBots Followers')
plt.legend(loc='upper left')

# %%
#bots[bots.listedcount>10000]
condition = (bots.screen_name.str.contains("bot", case=False)==True)|(bots.description.str.contains("bot", case=False)==True)|(bots.location.isnull())|(bots.verified==False)

bots['screen_name_binary'] = (bots.screen_name.str.contains("bot", case=False)==True)
bots['location_binary'] = (bots.location.isnull())
bots['verified_binary'] = (bots.verified==False)
bots.shape
# Out:
# (1321, 24)

# %%
df = pd.concat([bots, nonbots])
df.shape
# Out:
# (2797, 24)

# %%
df.corr(method='spearman')
# Out:
#                              id  followers_count  friends_count  listed_count  \
# id                     1.000000        -0.672925      -0.402346     -0.615005
# followers_count       -0.672925         1.000000       0.375522      0.896126
# friends_count         -0.402346         0.375522       1.000000      0.204403
# listed_count          -0.615005         0.896126       0.204403      1.000000
# favourites_count      -0.439430         0.457363       0.641529      0.349059
# verified              -0.611899         0.709732       0.356452      0.694340
# statuses_count        -0.451945         0.649117       0.111118      0.684976
# default_profile        0.522990        -0.496899      -0.296358     -0.447376
# default_profile_image  0.166601        -0.293838      -0.097607     -0.269035
# bot                    0.652131        -0.468430      -0.483105     -0.318445
# friends_by_followers   0.270435        -0.577157       0.427638     -0.681034
#
#                        favourites_count  verified  statuses_count  \
# id                            -0.439430 -0.611899       -0.451945
# followers_count                0.457363  0.709732        0.649117
# friends_count                  0.641529  0.356452        0.111118
# listed_count                   0.349059  0.694340        0.684976
# favourites_count               1.000000  0.394227        0.295108
# verified                       0.394227  1.000000        0.333278
# statuses_count                 0.295108  0.333278        1.000000
# default_profile               -0.348043 -0.404650       -0.375918
# default_profile_image         -0.226956 -0.132298       -0.289999
# bot                           -0.526228 -0.508555       -0.089018
# friends_by_followers           0.104797 -0.419815       -0.533971
#
#                        default_profile  default_profile_image       bot  \
# id                            0.522990               0.166601  0.652131
# followers_count              -0.496899              -0.293838 -0.468430
# friends_count                -0.296358              -0.097607 -0.483105
# listed_count                 -0.447376              -0.269035 -0.318445
# favourites_count             -0.348043              -0.226956 -0.526228
# verified                     -0.404650              -0.132298 -0.508555
# statuses_count               -0.375918              -0.289999 -0.089018
# default_profile               1.000000               0.246979  0.407748
# default_profile_image         0.246979               1.000000  0.139669
# bot                           0.407748               0.139669  1.000000
# friends_by_followers          0.197929               0.190986 -0.044056
#
#                        friends_by_followers
# id                                 0.270435
# followers_count                   -0.577157
# friends_count                      0.427638
# listed_count                      -0.681034
# favourites_count                   0.104797
# verified                          -0.419815
# statuses_count                    -0.533971
# default_profile                    0.197929
# default_profile_image              0.190986
# bot                               -0.044056
# friends_by_followers               1.000000

# %%
plt.figure(figsize=(8,4))
sns.heatmap(df.corr(method='spearman'), cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
filepath = 'C:/Users/Rutwik/OneDrive/Desktop/Twitter Bots vs Humans/kaggle_data'
file = filepath + '/training_data_2_csv_UTF.csv'

training_dataset = pd.read_csv(file)

bag_of_words_bot = r'bot|b0t|cannabis|tweet me|mishear|follow me|updates every|gorilla|yes_ofc|forget' \
                    r'expos|kill|clit|bbb|butt|fuck|XXX|sex|truthe|fake|anony|free|virus|funky|RNA|kuck|jargon' \
                    r'nerd|swag|jack|bang|bonsai|chick|prison|paper|pokem|xx|freak|ffd|dunia|clone|genie|bbb' \
                    r'ffd|onlyman|emoji|joke|troll|droop|free|every|wow|cheese|yeah|bio|magic|wizard|face'
            
training_dataset['screen_name_binary'] = training_dataset.screen_name.str.contains(bag_of_words_bot, case=False, na=False)
training_dataset['name_binary'] = training_dataset.name.str.contains(bag_of_words_bot, case=False, na=False)
training_dataset['description_binary'] = training_dataset.description.str.contains(bag_of_words_bot, case=False, na=False)
training_dataset['status_binary'] = training_dataset.status.str.contains(bag_of_words_bot, case=False, na=False)

# %%
training_dataset['listed_count_binary'] = (training_dataset.listed_count>20000)==False
features = ['screen_name_binary', 'name_binary', 'description_binary', 'status_binary', 'verified', 'followers_count', 'friends_count', 'statuses_count', 'listed_count_binary', 'bot']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.model_selection import train_test_split

X = training_dataset[features].iloc[:,:-1]
y = training_dataset[features].iloc[:,-1]

dt = DecisionTreeClassifier(criterion='entropy', min_samples_leaf=50, min_samples_split=10)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

dt = dt.fit(X_train, y_train)
y_pred_train = dt.predict(X_train)
y_pred_test = dt.predict(X_test)

print("Trainig Accuracy: %.5f" %accuracy_score(y_train, y_pred_train))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test))
# Out:
# Trainig Accuracy: 0.88707
# Test Accuracy: 0.87857

# %%
sns.set(font_scale=1.5)
sns.set_style("whitegrid", {'axes.grid' : False})

scores_train = dt.predict_proba(X_train)
scores_test = dt.predict_proba(X_test)

y_scores_train = []
y_scores_test = []
for i in range(len(scores_train)):
    y_scores_train.append(scores_train[i][1])

for i in range(len(scores_test)):
    y_scores_test.append(scores_test[i][1])
    
fpr_dt_train, tpr_dt_train, _ = roc_curve(y_train, y_scores_train, pos_label=1)
fpr_dt_test, tpr_dt_test, _ = roc_curve(y_test, y_scores_test, pos_label=1)

plt.plot(fpr_dt_train, tpr_dt_train, color='darkblue', label='Train AUC: %5f' %auc(fpr_dt_train, tpr_dt_train))
plt.plot(fpr_dt_test, tpr_dt_test, color='red', ls='--', label='Test AUC: %5f' %auc(fpr_dt_test, tpr_dt_test))
plt.title("Decision Tree ROC Curve")
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.legend(loc='lower right')

# %%
from sklearn.naive_bayes import MultinomialNB

X = training_dataset[features].iloc[:,:-1]
y = training_dataset[features].iloc[:,-1]

mnb = MultinomialNB(alpha=0.0009)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

mnb = mnb.fit(X_train, y_train)
y_pred_train = mnb.predict(X_train)
y_pred_test = mnb.predict(X_test)

print("Trainig Accuracy: %.5f" %accuracy_score(y_train, y_pred_train))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test))
# Out:
# Trainig Accuracy: 0.67961
# Test Accuracy: 0.69762

# %%
sns.set_style("whitegrid", {'axes.grid' : False})

scores_train = mnb.predict_proba(X_train)
scores_test = mnb.predict_proba(X_test)

y_scores_train = []
y_scores_test = []
for i in range(len(scores_train)):
    y_scores_train.append(scores_train[i][1])

for i in range(len(scores_test)):
    y_scores_test.append(scores_test[i][1])
    
fpr_mnb_train, tpr_mnb_train, _ = roc_curve(y_train, y_scores_train, pos_label=1)
fpr_mnb_test, tpr_mnb_test, _ = roc_curve(y_test, y_scores_test, pos_label=1)

plt.plot(fpr_mnb_train, tpr_mnb_train, color='darkblue', label='Train AUC: %5f' %auc(fpr_mnb_train, tpr_mnb_train))
plt.plot(fpr_mnb_test, tpr_mnb_test, color='red', ls='--', label='Test AUC: %5f' %auc(fpr_mnb_test, tpr_mnb_test))
plt.title("Multinomial NB ROC Curve")
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.legend(loc='lower right')

# %%
from sklearn.ensemble import RandomForestClassifier

X = training_dataset[features].iloc[:,:-1]
y = training_dataset[features].iloc[:,-1]

rf = RandomForestClassifier(criterion='entropy', min_samples_leaf=100, min_samples_split=20)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

rf = rf.fit(X_train, y_train)
y_pred_train = rf.predict(X_train)
y_pred_test = rf.predict(X_test)

print("Trainig Accuracy: %.5f" %accuracy_score(y_train, y_pred_train))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test))
# Out:
# Trainig Accuracy: 0.87634
# Test Accuracy: 0.86190

# %%
sns.set_style("whitegrid", {'axes.grid' : False})

scores_train = rf.predict_proba(X_train)
scores_test = rf.predict_proba(X_test)

y_scores_train = []
y_scores_test = []
for i in range(len(scores_train)):
    y_scores_train.append(scores_train[i][1])

for i in range(len(scores_test)):
    y_scores_test.append(scores_test[i][1])
    
fpr_rf_train, tpr_rf_train, _ = roc_curve(y_train, y_scores_train, pos_label=1)
fpr_rf_test, tpr_rf_test, _ = roc_curve(y_test, y_scores_test, pos_label=1)

plt.plot(fpr_rf_train, tpr_rf_train, color='darkblue', label='Train AUC: %5f' %auc(fpr_rf_train, tpr_rf_train))
plt.plot(fpr_rf_test, tpr_rf_test, color='red', ls='--', label='Test AUC: %5f' %auc(fpr_rf_test, tpr_rf_test))
plt.title("Random ForestROC Curve")
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.legend(loc='lower right')

# %%
#svm
X = training_dataset[features].iloc[:,:-1]
y = training_dataset[features].iloc[:,-1] 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

from sklearn.svm import SVC
classifier = SVC(probability=True)
classifier.fit(X_train, y_train)


y_pred_train = rf.predict(X_train)
y_pred_test = rf.predict(X_test)

print("Trainig Accuracy: %.5f" %accuracy_score(y_train, y_pred_train))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test))
# Out:
# Trainig Accuracy: 0.87634
# Test Accuracy: 0.86190

# %%
sns.set_style("whitegrid", {'axes.grid' : False})

scores_train = classifier.predict_proba(X_train)
scores_test = classifier.predict_proba(X_test)

y_scores_train = []
y_scores_test = []
for i in range(len(scores_train)):
    y_scores_train.append(scores_train[i][1])

for i in range(len(scores_test)):
    y_scores_test.append(scores_test[i][1])
    
fpr_rf_train, tpr_rf_train, _ = roc_curve(y_train, y_scores_train, pos_label=1)
fpr_rf_test, tpr_rf_test, _ = roc_curve(y_test, y_scores_test, pos_label=1)

plt.plot(fpr_rf_train, tpr_rf_train, color='darkblue', label='Train AUC: %5f' %auc(fpr_rf_train, tpr_rf_train))
plt.plot(fpr_rf_test, tpr_rf_test, color='red', ls='--', label='Test AUC: %5f' %auc(fpr_rf_test, tpr_rf_test))
plt.title("SVC")
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.legend(loc='lower right')

# %%
X = training_dataset[features].iloc[:,:-1]
y = training_dataset[features].iloc[:,-1]

X = np.asarray(X).astype(np.float32)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

#neural networks
import tensorflow as tf
ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(units = 10, activation = 'relu'))
ann.add(tf.keras.layers.Dense(units = 5, activation = 'relu'))
ann.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))


ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

ann.fit(X_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 62/62 [==============================] - 1s 3ms/step - loss: 595.6140 - accuracy: 0.6413
# Epoch 2/200
# 62/62 [==============================] - 0s 3ms/step - loss: 118.1254 - accuracy: 0.6852
# Epoch 3/200
# 62/62 [==============================] - 0s 3ms/step - loss: 77.2885 - accuracy: 0.6546
# Epoch 4/200
# 62/62 [==============================] - 0s 3ms/step - loss: 67.0505 - accuracy: 0.6919
# Epoch 5/200
# 62/62 [==============================] - 0s 3ms/step - loss: 66.9216 - accuracy: 0.6663
# Epoch 6/200
# 62/62 [==============================] - 0s 3ms/step - loss: 60.5361 - accuracy: 0.7026
# Epoch 7/200
# 62/62 [==============================] - 0s 3ms/step - loss: 65.7965 - accuracy: 0.7113
# Epoch 8/200
# 62/62 [==============================] - 0s 3ms/step - loss: 50.8590 - accuracy: 0.6832
# Epoch 9/200
# 62/62 [==============================] - 0s 4ms/step - loss: 55.2359 - accuracy: 0.7077
# Epoch 10/200
# 62/62 [==============================] - 0s 3ms/step - loss: 38.3898 - accuracy: 0.7123
# Epoch 11/200
# 62/62 [==============================] - 0s 3ms/step - loss: 34.2735 - accuracy: 0.7159
# Epoch 12/200
# 62/62 [==============================] - 0s 3ms/step - loss: 32.4937 - accuracy: 0.7230
# Epoch 13/200
# 62/62 [==============================] - 0s 3ms/step - loss: 47.4009 - accuracy: 0.7133
# Epoch 14/200
# 62/62 [==============================] - 0s 4ms/step - loss: 24.0412 - accuracy: 0.7506
# Epoch 15/200
# 62/62 [==============================] - 0s 4ms/step - loss: 35.9480 - accuracy: 0.7225
# Epoch 16/200
# 62/62 [==============================] - 0s 4ms/step - loss: 37.3626 - accuracy: 0.7190
# Epoch 17/200
# 62/62 [==============================] - 0s 3ms/step - loss: 41.8916 - accuracy: 0.7287
# Epoch 18/200
# 62/62 [==============================] - 0s 4ms/step - loss: 34.7765 - accuracy: 0.7098
# Epoch 19/200
# 62/62 [==============================] - 0s 3ms/step - loss: 39.6867 - accuracy: 0.7297
# Epoch 20/200
# 62/62 [==============================] - 0s 3ms/step - loss: 290.1979 - accuracy: 0.6714
# Epoch 21/200
# 62/62 [==============================] - 0s 3ms/step - loss: 70.9358 - accuracy: 0.7307
# Epoch 22/200
# 62/62 [==============================] - 0s 3ms/step - loss: 35.0655 - accuracy: 0.7547
# Epoch 23/200
# 62/62 [==============================] - 0s 3ms/step - loss: 61.0542 - accuracy: 0.6960
# Epoch 24/200
# 62/62 [==============================] - 0s 3ms/step - loss: 28.3855 - accuracy: 0.7552
# Epoch 25/200
# 62/62 [==============================] - 0s 3ms/step - loss: 22.6065 - accuracy: 0.7568
# Epoch 26/200
# 62/62 [==============================] - 0s 4ms/step - loss: 19.9741 - accuracy: 0.7547
# Epoch 27/200
# 62/62 [==============================] - 0s 3ms/step - loss: 42.5212 - accuracy: 0.7655
# Epoch 28/200
# 62/62 [==============================] - 0s 3ms/step - loss: 31.6145 - accuracy: 0.7511
# Epoch 29/200
# 62/62 [==============================] - 0s 3ms/step - loss: 34.6662 - accuracy: 0.7246
# Epoch 30/200
# 62/62 [==============================] - 0s 4ms/step - loss: 21.7858 - accuracy: 0.7598
# Epoch 31/200
# 62/62 [==============================] - 0s 4ms/step - loss: 27.2952 - accuracy: 0.7609
# Epoch 32/200
# 62/62 [==============================] - 0s 4ms/step - loss: 22.4558 - accuracy: 0.7685
# Epoch 33/200
# 62/62 [==============================] - 0s 3ms/step - loss: 20.2323 - accuracy: 0.7787
# Epoch 34/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.9121 - accuracy: 0.7762
# Epoch 35/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.6801 - accuracy: 0.7946
# Epoch 36/200
# 62/62 [==============================] - 0s 3ms/step - loss: 25.1066 - accuracy: 0.7721
# Epoch 37/200
# 62/62 [==============================] - 0s 3ms/step - loss: 38.2467 - accuracy: 0.7706
# Epoch 38/200
# 62/62 [==============================] - 0s 3ms/step - loss: 186.9256 - accuracy: 0.7067
# Epoch 39/200
# 62/62 [==============================] - 0s 3ms/step - loss: 63.6714 - accuracy: 0.7844
# Epoch 40/200
# 62/62 [==============================] - 0s 3ms/step - loss: 26.8576 - accuracy: 0.7976
# Epoch 41/200
# 62/62 [==============================] - 0s 4ms/step - loss: 30.7889 - accuracy: 0.7971
# Epoch 42/200
# 62/62 [==============================] - 0s 4ms/step - loss: 15.6459 - accuracy: 0.8038
# Epoch 43/200
# 62/62 [==============================] - 0s 4ms/step - loss: 19.7330 - accuracy: 0.7961
# Epoch 44/200
# 62/62 [==============================] - 0s 3ms/step - loss: 20.4716 - accuracy: 0.7992
# Epoch 45/200
# 62/62 [==============================] - 0s 3ms/step - loss: 14.7725 - accuracy: 0.8166
# Epoch 46/200
# 62/62 [==============================] - 0s 4ms/step - loss: 23.3499 - accuracy: 0.8012
# Epoch 47/200
# 62/62 [==============================] - 0s 4ms/step - loss: 30.8201 - accuracy: 0.7890
# Epoch 48/200
# 62/62 [==============================] - 0s 4ms/step - loss: 39.1422 - accuracy: 0.7598
# Epoch 49/200
# 62/62 [==============================] - 0s 4ms/step - loss: 25.6545 - accuracy: 0.7992
# Epoch 50/200
# 62/62 [==============================] - 0s 3ms/step - loss: 37.4627 - accuracy: 0.7598
# Epoch 51/200
# 62/62 [==============================] - 0s 3ms/step - loss: 41.9476 - accuracy: 0.7690
# Epoch 52/200
# 62/62 [==============================] - 0s 3ms/step - loss: 73.5347 - accuracy: 0.7695
# Epoch 53/200
# 62/62 [==============================] - 0s 3ms/step - loss: 31.9634 - accuracy: 0.7925
# Epoch 54/200
# 62/62 [==============================] - 0s 4ms/step - loss: 53.7935 - accuracy: 0.7619
# Epoch 55/200
# 62/62 [==============================] - 0s 4ms/step - loss: 51.4991 - accuracy: 0.7665
# Epoch 56/200
# 62/62 [==============================] - 0s 4ms/step - loss: 148.7461 - accuracy: 0.7414
# Epoch 57/200
# 62/62 [==============================] - 0s 4ms/step - loss: 69.1459 - accuracy: 0.7849
# Epoch 58/200
# 62/62 [==============================] - 0s 3ms/step - loss: 34.7674 - accuracy: 0.7747
# Epoch 59/200
# 62/62 [==============================] - 0s 3ms/step - loss: 26.5136 - accuracy: 0.7966
# Epoch 60/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.8404 - accuracy: 0.8135
# Epoch 61/200
# 62/62 [==============================] - 0s 3ms/step - loss: 15.3021 - accuracy: 0.8298
# Epoch 62/200
# 62/62 [==============================] - 0s 4ms/step - loss: 15.9423 - accuracy: 0.8278
# Epoch 63/200
# 62/62 [==============================] - 0s 4ms/step - loss: 15.2309 - accuracy: 0.8160
# Epoch 64/200
# 62/62 [==============================] - 0s 3ms/step - loss: 22.5623 - accuracy: 0.8222
# Epoch 65/200
# 62/62 [==============================] - 0s 3ms/step - loss: 11.5546 - accuracy: 0.8263
# Epoch 66/200
# 62/62 [==============================] - 0s 3ms/step - loss: 22.6792 - accuracy: 0.8125
# Epoch 67/200
# 62/62 [==============================] - 0s 3ms/step - loss: 14.3347 - accuracy: 0.8380
# Epoch 68/200
# 62/62 [==============================] - 0s 3ms/step - loss: 69.1916 - accuracy: 0.7736
# Epoch 69/200
# 62/62 [==============================] - 0s 3ms/step - loss: 133.1558 - accuracy: 0.7885
# Epoch 70/200
# 62/62 [==============================] - 0s 3ms/step - loss: 47.8811 - accuracy: 0.7874
# Epoch 71/200
# 62/62 [==============================] - 0s 3ms/step - loss: 27.2664 - accuracy: 0.8145
# Epoch 72/200
# 62/62 [==============================] - 0s 3ms/step - loss: 63.5416 - accuracy: 0.7716
# Epoch 73/200
# 62/62 [==============================] - 0s 3ms/step - loss: 126.6707 - accuracy: 0.7890
# Epoch 74/200
# 62/62 [==============================] - 0s 3ms/step - loss: 50.0282 - accuracy: 0.8120
# Epoch 75/200
# 62/62 [==============================] - 0s 3ms/step - loss: 20.0861 - accuracy: 0.8242
# Epoch 76/200
# 62/62 [==============================] - 0s 3ms/step - loss: 16.4715 - accuracy: 0.8171
# Epoch 77/200
# 62/62 [==============================] - 0s 3ms/step - loss: 24.3399 - accuracy: 0.7982
# Epoch 78/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.0921 - accuracy: 0.8186
# Epoch 79/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.9662 - accuracy: 0.8171
# Epoch 80/200
# 62/62 [==============================] - 0s 3ms/step - loss: 14.7204 - accuracy: 0.8252
# Epoch 81/200
# 62/62 [==============================] - 0s 3ms/step - loss: 22.0004 - accuracy: 0.8048
# Epoch 82/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.9712 - accuracy: 0.8237
# Epoch 83/200
# 62/62 [==============================] - 0s 3ms/step - loss: 15.1403 - accuracy: 0.8380
# Epoch 84/200
# 62/62 [==============================] - 0s 3ms/step - loss: 28.1787 - accuracy: 0.8278
# Epoch 85/200
# 62/62 [==============================] - 0s 3ms/step - loss: 131.6951 - accuracy: 0.7537
# Epoch 86/200
# 62/62 [==============================] - 0s 3ms/step - loss: 37.3560 - accuracy: 0.8206
# Epoch 87/200
# 62/62 [==============================] - 0s 4ms/step - loss: 25.5960 - accuracy: 0.8007
# Epoch 88/200
# 62/62 [==============================] - 0s 3ms/step - loss: 21.2872 - accuracy: 0.8171
# Epoch 89/200
# 62/62 [==============================] - 0s 3ms/step - loss: 24.0073 - accuracy: 0.8293
# Epoch 90/200
# 62/62 [==============================] - 0s 3ms/step - loss: 22.2852 - accuracy: 0.8212
# Epoch 91/200
# 62/62 [==============================] - 0s 3ms/step - loss: 27.4062 - accuracy: 0.8022
# Epoch 92/200
# 62/62 [==============================] - 0s 3ms/step - loss: 25.8483 - accuracy: 0.8125
# Epoch 93/200
# 62/62 [==============================] - 0s 3ms/step - loss: 14.7842 - accuracy: 0.8334
# Epoch 94/200
# 62/62 [==============================] - 0s 3ms/step - loss: 11.2123 - accuracy: 0.8293
# Epoch 95/200
# 62/62 [==============================] - 0s 3ms/step - loss: 26.5672 - accuracy: 0.8094
# Epoch 96/200
# 62/62 [==============================] - 0s 5ms/step - loss: 25.8553 - accuracy: 0.7961
# Epoch 97/200
# 62/62 [==============================] - 0s 5ms/step - loss: 31.9277 - accuracy: 0.7976
# Epoch 98/200
# 62/62 [==============================] - 0s 4ms/step - loss: 83.4351 - accuracy: 0.7695
# Epoch 99/200
# 62/62 [==============================] - 0s 4ms/step - loss: 112.2236 - accuracy: 0.7941
# Epoch 100/200
# 62/62 [==============================] - 0s 5ms/step - loss: 51.0327 - accuracy: 0.8191
# Epoch 101/200
# 62/62 [==============================] - 0s 3ms/step - loss: 25.6841 - accuracy: 0.7818
# Epoch 102/200
# 62/62 [==============================] - 0s 3ms/step - loss: 24.9767 - accuracy: 0.7793
# Epoch 103/200
# 62/62 [==============================] - 0s 3ms/step - loss: 21.1931 - accuracy: 0.7900
# Epoch 104/200
# 62/62 [==============================] - 0s 4ms/step - loss: 19.3169 - accuracy: 0.8063
# Epoch 105/200
# 62/62 [==============================] - 0s 3ms/step - loss: 10.5878 - accuracy: 0.8114
# Epoch 106/200
# 62/62 [==============================] - 0s 4ms/step - loss: 21.4168 - accuracy: 0.7987
# Epoch 107/200
# 62/62 [==============================] - 0s 5ms/step - loss: 10.2944 - accuracy: 0.8114
# Epoch 108/200
# 62/62 [==============================] - 0s 3ms/step - loss: 12.3137 - accuracy: 0.8053
# Epoch 109/200
# 62/62 [==============================] - 0s 4ms/step - loss: 12.8904 - accuracy: 0.8196
# Epoch 110/200
# 62/62 [==============================] - 0s 4ms/step - loss: 20.4574 - accuracy: 0.7910
# Epoch 111/200
# 62/62 [==============================] - 0s 3ms/step - loss: 48.9009 - accuracy: 0.8017
# Epoch 112/200
# 62/62 [==============================] - 0s 4ms/step - loss: 14.8551 - accuracy: 0.7925
# Epoch 113/200
# 62/62 [==============================] - 0s 4ms/step - loss: 67.9007 - accuracy: 0.7951
# Epoch 114/200
# 62/62 [==============================] - 0s 4ms/step - loss: 68.0929 - accuracy: 0.7747
# Epoch 115/200
# 62/62 [==============================] - 0s 4ms/step - loss: 18.0484 - accuracy: 0.8201
# Epoch 116/200
# 62/62 [==============================] - 0s 3ms/step - loss: 23.0491 - accuracy: 0.7982
# Epoch 117/200
# 62/62 [==============================] - 0s 3ms/step - loss: 23.1259 - accuracy: 0.8068
# Epoch 118/200
# 62/62 [==============================] - 0s 3ms/step - loss: 21.8371 - accuracy: 0.8206
# Epoch 119/200
# 62/62 [==============================] - 0s 3ms/step - loss: 15.2474 - accuracy: 0.8171
# Epoch 120/200
# 62/62 [==============================] - ETA: 0s - loss: 100.0202 - accuracy: 0.75 - 0s 3ms/step - loss: 99.6729 - accuracy: 0.7511
# Epoch 121/200
# 62/62 [==============================] - 0s 3ms/step - loss: 30.6951 - accuracy: 0.8217
# Epoch 122/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.1310 - accuracy: 0.8140
# Epoch 123/200
# 62/62 [==============================] - 0s 3ms/step - loss: 9.9805 - accuracy: 0.8068
# Epoch 124/200
# 62/62 [==============================] - 0s 3ms/step - loss: 12.5225 - accuracy: 0.8135
# Epoch 125/200
# 62/62 [==============================] - 0s 3ms/step - loss: 25.2803 - accuracy: 0.8125
# Epoch 126/200
# 62/62 [==============================] - 0s 3ms/step - loss: 9.0296 - accuracy: 0.8283
# Epoch 127/200
# 62/62 [==============================] - 0s 3ms/step - loss: 8.9797 - accuracy: 0.8273
# Epoch 128/200
# 62/62 [==============================] - 0s 3ms/step - loss: 14.6765 - accuracy: 0.8063
# Epoch 129/200
# 62/62 [==============================] - 0s 3ms/step - loss: 8.5734 - accuracy: 0.8227
# Epoch 130/200
# 62/62 [==============================] - 0s 3ms/step - loss: 9.3579 - accuracy: 0.8201
# Epoch 131/200
# 62/62 [==============================] - 0s 3ms/step - loss: 15.8401 - accuracy: 0.8058
# Epoch 132/200
# 62/62 [==============================] - 0s 4ms/step - loss: 25.4862 - accuracy: 0.8186
# Epoch 133/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.4864 - accuracy: 0.8217
# Epoch 134/200
# 62/62 [==============================] - 0s 3ms/step - loss: 29.4956 - accuracy: 0.7971
# Epoch 135/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.5448 - accuracy: 0.8094
# Epoch 136/200
# 62/62 [==============================] - 0s 3ms/step - loss: 10.5663 - accuracy: 0.8242
# Epoch 137/200
# 62/62 [==============================] - 0s 4ms/step - loss: 15.7434 - accuracy: 0.8135
# Epoch 138/200
# 62/62 [==============================] - 0s 3ms/step - loss: 16.1720 - accuracy: 0.8196
# Epoch 139/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.8226 - accuracy: 0.8350
# Epoch 140/200
# 62/62 [==============================] - 0s 4ms/step - loss: 29.5422 - accuracy: 0.8094
# Epoch 141/200
# 62/62 [==============================] - 0s 4ms/step - loss: 14.3447 - accuracy: 0.8247
# Epoch 142/200
# 62/62 [==============================] - 0s 3ms/step - loss: 26.3570 - accuracy: 0.7976
# Epoch 143/200
# 62/62 [==============================] - 0s 4ms/step - loss: 21.7714 - accuracy: 0.8125
# Epoch 144/200
# 62/62 [==============================] - 0s 5ms/step - loss: 25.8558 - accuracy: 0.8339
# Epoch 145/200
# 62/62 [==============================] - 0s 4ms/step - loss: 11.8356 - accuracy: 0.8283
# Epoch 146/200
# 62/62 [==============================] - 0s 3ms/step - loss: 17.3081 - accuracy: 0.8288
# Epoch 147/200
# 62/62 [==============================] - 0s 3ms/step - loss: 17.0757 - accuracy: 0.8298
# Epoch 148/200
# 62/62 [==============================] - 0s 3ms/step - loss: 14.6152 - accuracy: 0.8227
# Epoch 149/200
# 62/62 [==============================] - 0s 3ms/step - loss: 36.9480 - accuracy: 0.7854
# Epoch 150/200
# 62/62 [==============================] - 0s 3ms/step - loss: 23.7505 - accuracy: 0.8263
# Epoch 151/200
# 62/62 [==============================] - 0s 3ms/step - loss: 16.7171 - accuracy: 0.8022
# Epoch 152/200
# 62/62 [==============================] - 0s 3ms/step - loss: 12.8840 - accuracy: 0.8304
# Epoch 153/200
# 62/62 [==============================] - 0s 4ms/step - loss: 9.5640 - accuracy: 0.8278
# Epoch 154/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.0493 - accuracy: 0.8140
# Epoch 155/200
# 62/62 [==============================] - 0s 3ms/step - loss: 45.6397 - accuracy: 0.8145
# Epoch 156/200
# 62/62 [==============================] - 0s 3ms/step - loss: 20.4967 - accuracy: 0.8171
# Epoch 157/200
# 62/62 [==============================] - 0s 4ms/step - loss: 39.6189 - accuracy: 0.7777
# Epoch 158/200
# 62/62 [==============================] - 0s 3ms/step - loss: 154.8914 - accuracy: 0.8120
# Epoch 159/200
# 62/62 [==============================] - 0s 3ms/step - loss: 52.7707 - accuracy: 0.8258
# Epoch 160/200
# 62/62 [==============================] - 0s 3ms/step - loss: 27.7967 - accuracy: 0.8150
# Epoch 161/200
# 62/62 [==============================] - 0s 3ms/step - loss: 21.0971 - accuracy: 0.8304
# Epoch 162/200
# 62/62 [==============================] - 0s 4ms/step - loss: 24.0222 - accuracy: 0.8258
# Epoch 163/200
# 62/62 [==============================] - 0s 3ms/step - loss: 20.0709 - accuracy: 0.8344
# Epoch 164/200
# 62/62 [==============================] - 0s 3ms/step - loss: 17.1630 - accuracy: 0.8283
# Epoch 165/200
# 62/62 [==============================] - 0s 3ms/step - loss: 29.6787 - accuracy: 0.8160
# Epoch 166/200
# 62/62 [==============================] - 0s 3ms/step - loss: 14.7716 - accuracy: 0.8273
# Epoch 167/200
# 62/62 [==============================] - 0s 3ms/step - loss: 11.7082 - accuracy: 0.8452
# Epoch 168/200
# 62/62 [==============================] - 0s 3ms/step - loss: 8.1629 - accuracy: 0.8421
# Epoch 169/200
# 62/62 [==============================] - 0s 3ms/step - loss: 8.7581 - accuracy: 0.8370
# Epoch 170/200
# 62/62 [==============================] - 0s 3ms/step - loss: 20.6588 - accuracy: 0.8155
# Epoch 171/200
# 62/62 [==============================] - 0s 3ms/step - loss: 11.9957 - accuracy: 0.8043
# Epoch 172/200
# 62/62 [==============================] - 0s 3ms/step - loss: 9.2184 - accuracy: 0.8493
# Epoch 173/200
# 62/62 [==============================] - 0s 4ms/step - loss: 9.3577 - accuracy: 0.8314
# Epoch 174/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.1987 - accuracy: 0.8355
# Epoch 175/200
# 62/62 [==============================] - 0s 3ms/step - loss: 16.2630 - accuracy: 0.8227
# Epoch 176/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.8275 - accuracy: 0.8416
# Epoch 177/200
# 62/62 [==============================] - 0s 3ms/step - loss: 17.9839 - accuracy: 0.8171
# Epoch 178/200
# 62/62 [==============================] - 0s 3ms/step - loss: 8.5267 - accuracy: 0.8457
# Epoch 179/200
# 62/62 [==============================] - 0s 3ms/step - loss: 8.8476 - accuracy: 0.8390
# Epoch 180/200
# 62/62 [==============================] - 0s 4ms/step - loss: 12.0784 - accuracy: 0.8513
# Epoch 181/200
# 62/62 [==============================] - 0s 3ms/step - loss: 9.5763 - accuracy: 0.8406
# Epoch 182/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.9118 - accuracy: 0.8212
# Epoch 183/200
# 62/62 [==============================] - 0s 3ms/step - loss: 7.8735 - accuracy: 0.8436
# Epoch 184/200
# 62/62 [==============================] - 0s 3ms/step - loss: 7.9746 - accuracy: 0.8339
# Epoch 185/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.8445 - accuracy: 0.8319
# Epoch 186/200
# 62/62 [==============================] - 0s 4ms/step - loss: 22.6108 - accuracy: 0.8007
# Epoch 187/200
# 62/62 [==============================] - 0s 3ms/step - loss: 17.1558 - accuracy: 0.8319
# Epoch 188/200
# 62/62 [==============================] - 0s 3ms/step - loss: 5.9433 - accuracy: 0.8436
# Epoch 189/200
# 62/62 [==============================] - 0s 3ms/step - loss: 17.8145 - accuracy: 0.8304
# Epoch 190/200
# 62/62 [==============================] - 0s 3ms/step - loss: 8.7790 - accuracy: 0.8467
# Epoch 191/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.4130 - accuracy: 0.8431
# Epoch 192/200
# 62/62 [==============================] - 0s 3ms/step - loss: 8.4500 - accuracy: 0.8309
# Epoch 193/200
# 62/62 [==============================] - 0s 3ms/step - loss: 13.9262 - accuracy: 0.8380
# Epoch 194/200
# 62/62 [==============================] - 0s 3ms/step - loss: 11.3856 - accuracy: 0.8314
# Epoch 195/200
# 62/62 [==============================] - 0s 3ms/step - loss: 18.1744 - accuracy: 0.8288
# Epoch 196/200
# 62/62 [==============================] - 0s 3ms/step - loss: 21.9643 - accuracy: 0.8263
# Epoch 197/200
# 62/62 [==============================] - 0s 3ms/step - loss: 10.9313 - accuracy: 0.8416
# Epoch 198/200
# 62/62 [==============================] - 0s 4ms/step - loss: 15.2030 - accuracy: 0.8355
# Epoch 199/200
# 62/62 [==============================] - 0s 3ms/step - loss: 26.0779 - accuracy: 0.8176
# Epoch 200/200
# 62/62 [==============================] - 0s 3ms/step - loss: 9.5809 - accuracy: 0.8314
